# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/cbook.py:128: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the matplotlib toolkit finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
images = os.listdir('test/')

# %%
images
# Out:
# ['19#Sharanam Gachami Rohingatanu.jpg',
#  '3#Arnab.jpg',
#  '3#Dhimani.jpg',
#  '19#Lal.jpg',
#  '15#Chameli Devi.jpg',
#  '12#Suxxex.jpg',
#  '4#Karnataka.jpg',
#  '14#Konidela.jpg',
#  '10#visakhaPatnam.jpg',
#  '20#Lata Garu Chinnipilla.jpg',
#  '6#visakhaPatnam.jpg',
#  '4#Telaga Nadima.jpg',
#  '9#Kumar.jpg',
#  '19#Saini.jpg',
#  '6#Karnataka.jpg',
#  '29#Srimata Rani Nizamabad.jpg',
#  '1#india.jpg',
#  '10#Suxxex.jpg',
#  '2#Sahoo.jpg',
#  '17#Srimata Rani Nizamabad.jpg',
#  '4#Kirti nagar.jpg',
#  '19#Srimata Rani Nizamabad.jpg',
#  '5#india.jpg',
#  '8#england.jpg',
#  '8#New York.jpg',
#  '22#Suraj.jpg',
#  '25#Saini.jpg',
#  '7#Chameli Devi.jpg',
#  '5#shyam nagar.jpg',
#  '13#rajasthan.jpg',
#  '17#Kumari Reshma.jpg',
#  '19#agrasen inter-college.jpg',
#  '6#Nigeria.jpg',
#  '9#sahastralokama.jpg',
#  '34#Lal.jpg',
#  '5#Faridabad.jpg',
#  '18#Ramagaru Srikabala.jpg',
#  '8#Suxxex.jpg',
#  '2#visakhaPatnam.jpg',
#  '4#bangalore.jpg',
#  '31#agrasen inter-college.jpg',
# ...

# %%
for i in images:
#     img = cv2.imread('test/'+i)
#     plt.imshow(img)
#     plt.show()
    idx = int(str.split(i,'#')[0])
    label = str.split(str.split(i,'#')[1],'.jpg')[0]
    max_n = len(label)
    if label=='Lal':
        print label,min(max_n-1,idx-1)
# Out:
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 1
# Lal 2
# Lal 2
# Lal 2
# Lal 0
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
# Lal 2
